# %% [markdown]
# A variable is a container for a value, which can be of various types

# %% [markdown]
# <br>
# This is a <br>
# multiline comment<br>
# or docstring (used to define a functions purpose)<br>
# can be single or double quotes<br>

# %% [markdown]
# <br>
# VARIABLE RULES:<br>
#   - Variable names are case sensitive (name and NAME are different variables)<br>
#   - Must start with a letter or an underscore<br>
#   - Can have numbers but can not start with one<br>

# %% [markdown]
# x = 1           # int<br>
# y = 2.5         # float<br>
# name = 'John'   # str<br>
# is_cool = True  # bool

# %% [markdown]
# Multiple assignment

# %%
x, y, name, is_cool = (1, 2.5, 'John', True)

# %% [markdown]
# Basic math

# %%
a = x + y

# %% [markdown]
# Casting

# %%
x = str(x)
y = int(y)
z = float(y)

# %%
print(type(z), z)
